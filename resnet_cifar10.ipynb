# %%
from __future__ import print_function
import keras
import keras.layers
from keras.layers.normalization import BatchNormalization
from keras.layers import AveragePooling2D, Input, Flatten, Conv2D,Activation,Dense
from keras.optimizers import Adam
from keras.callbacks import ModelCheckpoint, LearningRateScheduler
from keras.callbacks import ReduceLROnPlateau
from keras.preprocessing.image import ImageDataGenerator
from keras.regularizers import l2
from keras.models import Model
from keras.datasets import cifar10
import numpy as np
import os

# Training parameters
batch_size = 32  # orig paper trained all networks with batch_size=128
epochs = 200
data_augmentation = True
num_classes = 10

# Subtracting pixel mean improves accuracy
subtract_pixel_mean = True

n = 3

# Model version
version = 1

# Computed depth from supplied model parameter n
if version == 1:
    depth = n * 4 + 2
elif version == 2:
    depth = n * 6 + 2

# Model name, depth and version
model_type = 'ResNet%dv%d' % (depth, version)

# Load the CIFAR10 data.
(x_train, y_train), (x_test, y_test) = cifar10.load_data()

# Input image dimensions.
input_shape = x_train.shape[1:]

# Normalize data.
x_train = x_train.astype('float32') / 255
x_test = x_test.astype('float32') / 255

# If subtract pixel mean is enabled
if subtract_pixel_mean:
    x_train_mean = np.mean(x_train, axis=0)
    x_train -= x_train_mean
    x_test -= x_train_mean

print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
print('y_train shape:', y_train.shape)

# Convert class vectors to binary class matrices.
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)


def lr_schedule(epoch):

    lr = 0.001
    if epoch > 180:
        lr *= 0.5e-3
    elif epoch > 160:
        lr *= 1e-3
    elif epoch > 120:
        lr *= 1e-2
    elif epoch > 80:
        lr *= 1e-1
    print('Learning rate: ', lr)
    return lr
#SCHEDULER

def resnet_layer(inputs,
                 num_filters=16,
                 kernel_size=3,
                 strides=1,
                 activation='relu',
                 batch_normalization=True,
                 conv_first=True):

    conv = Conv2D(num_filters,
                  kernel_size=kernel_size,
                  strides=strides,
                  padding='same',
                  kernel_initializer='he_normal',
                  kernel_regularizer=l2(1e-4))

    x = inputs
    if conv_first:
        x = conv(x)
        if batch_normalization:
            x = BatchNormalization()(x)
        if activation is not None:
            x = Activation(activation)(x)
    else:
        if batch_normalization:
            x = BatchNormalization()(x)
        if activation is not None:
            x = Activation(activation)(x)
        x = conv(x)
    return x


def resnet_v1(input_shape, depth, num_classes=10):

    if (depth - 2) % 6 != 0:
        raise ValueError('depth should be 6n+2 (eg 20, 32, 44 in [a])')
    
    num_filters = 16
    num_res_blocks = int((depth - 2) / 6)

    inputs = Input(shape=input_shape)
    x = resnet_layer(inputs=inputs)
    
    for stack in range(3):
        for res_block in range(num_res_blocks):
            strides = 1
            if stack > 0 and res_block == 0:  
                strides = 2  
            y = resnet_layer(inputs=x,
                             num_filters=num_filters,
                             strides=strides)
            y = resnet_layer(inputs=y,
                             num_filters=num_filters,
                             activation=None)
            if stack > 0 and res_block == 0: 
                x = resnet_layer(inputs=x,
                                 num_filters=num_filters,
                                 kernel_size=1,
                                 strides=strides,
                                 activation=None,
                                 batch_normalization=False)
            x = keras.layers.add([x, y])
            x = Activation('relu')(x)
        num_filters *= 2

    # Add classifier on top.
    # v1 does not use BN after last shortcut connection-ReLU
    x = AveragePooling2D(pool_size=8)(x)
    y = Flatten()(x)
    outputs = Dense(num_classes,
                    activation='softmax',
                    kernel_initializer='he_normal')(y)

    # Instantiate model.
    model = Model(inputs=inputs, outputs=outputs)
    return model


def resnet_v2(input_shape, depth, num_classes=10):
    
    if (depth - 2) % 9 != 0:
        raise ValueError('depth should be 9n+2 (eg 56 or 110 in [b])')
    # Start model definition.
    num_filters_in = 16
    num_res_blocks = int((depth - 2) / 9)

    inputs = Input(shape=input_shape)
    # v2 performs Conv2D with BN-ReLU on input before splitting into 2 paths
    x = resnet_layer(inputs=inputs,
                     num_filters=num_filters_in,
                     conv_first=True)

    # Instantiate the stack of residual units
    for stage in range(3):
        for res_block in range(num_res_blocks):
            activation = 'relu'
            batch_normalization = True
            strides = 1
            if stage == 0:
                num_filters_out = num_filters_in * 4
                if res_block == 0:  # first layer and first stage
                    activation = None
                    batch_normalization = False
            else:
                num_filters_out = num_filters_in * 2
                if res_block == 0:  # first layer but not first stage
                    strides = 2    # downsample

            # bottleneck residual unit
            y = resnet_layer(inputs=x,
                             num_filters=num_filters_in,
                             kernel_size=1,
                             strides=strides,
                             activation=activation,
                             batch_normalization=batch_normalization,
                             conv_first=False)
            y = resnet_layer(inputs=y,
                             num_filters=num_filters_in,
                             conv_first=False)
            y = resnet_layer(inputs=y,
                             num_filters=num_filters_out,
                             kernel_size=1,
                             conv_first=False)
            if res_block == 0:
                # linear projection residual shortcut connection to match
                # changed dims
                x = resnet_layer(inputs=x,
                                 num_filters=num_filters_out,
                                 kernel_size=1,
                                 strides=strides,
                                 activation=None,
                                 batch_normalization=False)
            x = keras.layers.add([x, y])

        num_filters_in = num_filters_out

    # Add classifier on top.
    # v2 has BN-ReLU before Pooling
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = AveragePooling2D(pool_size=8)(x)
    y = Flatten()(x)
    outputs = Dense(num_classes,
                    activation='Sigmoid',
                    kernel_initializer='he_normal')(y)

    # Instantiate model.
    model = Model(inputs=inputs, outputs=outputs)
    return model


if version == 2:
    model = resnet_v2(input_shape=input_shape, depth=depth)
else:
    model = resnet_v1(input_shape=input_shape, depth=depth)

model.compile(loss='categorical_crossentropy',
              optimizer=Adam(learning_rate=lr_schedule(0)),
              metrics=['accuracy'])
model.summary()
print(model_type)

# Prepare model model saving directory.
save_dir = os.path.join(os.getcwd(), 'saved_models')
model_name = 'cifar10_%s_model.{epoch:03d}.h5' % model_type
if not os.path.isdir(save_dir):
    os.makedirs(save_dir)
filepath = os.path.join(save_dir, model_name)

# Prepare callbacks for model saving and for learning rate adjustment.
checkpoint = ModelCheckpoint(filepath=filepath,
                             monitor='val_acc',
                             verbose=1,
                             save_best_only=True)

lr_scheduler = LearningRateScheduler(lr_schedule)

lr_reducer = ReduceLROnPlateau(factor=np.sqrt(0.1),
                               cooldown=0,
                               patience=5,
                               min_lr=0.5e-6)

callbacks = [checkpoint, lr_reducer, lr_scheduler]

# Run training, with or without data augmentation.
if not data_augmentation:
    print('Not using data augmentation.')
    model.fit(x_train, y_train,
              batch_size=batch_size,
              epochs=epochs,
              validation_data=(x_test, y_test),
              shuffle=True,
              callbacks=callbacks)
else:
    print('Using real-time data augmentation.')
    # This will do preprocessing and realtime data augmentation:
    datagen = ImageDataGenerator(
        # set input mean to 0 over the dataset
        featurewise_center=False,
        # set each sample mean to 0
        samplewise_center=False,
        # divide inputs by std of dataset
        featurewise_std_normalization=False,
        # divide each input by its std
        samplewise_std_normalization=False,
        # apply ZCA whitening
        zca_whitening=False,
        # epsilon for ZCA whitening
        zca_epsilon=1e-06,
        # randomly rotate images in the range (deg 0 to 180)
        rotation_range=0,
        # randomly shift images horizontally
        width_shift_range=0.1,
        # randomly shift images vertically
        height_shift_range=0.1,
        # set range for random shear
        shear_range=0.,
        # set range for random zoom
        zoom_range=0.,
        # set range for random channel shifts
        channel_shift_range=0.,
        # set mode for filling points outside the input boundaries
        fill_mode='nearest',
        # value used for fill_mode = "constant"
        cval=0.,
        # randomly flip images
        horizontal_flip=True,
        # randomly flip images
        vertical_flip=False,
        # set rescaling factor (applied before any other transformation)
        rescale=None,
        # set function that will be applied on each input
        preprocessing_function=None,
        # image data format, either "channels_first" or "channels_last"
        data_format=None,
        # fraction of images reserved for validation (strictly between 0 and 1)
        validation_split=0.0)

    # Compute quantities required for featurewise normalization
    # (std, mean, and principal components if ZCA whitening is applied).
    datagen.fit(x_train)

    # Fit the model on the batches generated by datagen.flow().
    model.fit_generator(datagen.flow(x_train, y_train, batch_size=batch_size),
                        validation_data=(x_test, y_test),
                        epochs=epochs, verbose=1, workers=4,
                        callbacks=callbacks)

# Score trained model.
scores = model.evaluate(x_test, y_test, verbose=1)
print('Test loss:', scores[0])
print('Test accuracy:', scores[1])
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 6s 0us/step
# x_train shape: (50000, 32, 32, 3)
# 50000 train samples
# 10000 test samples
# y_train shape: (50000, 1)
# Learning rate:  0.001
# Model: "functional_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 32, 32, 3)]  0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 32, 32, 16)   448         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 32, 32, 16)   64          conv2d[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 32, 32, 16)   0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 32, 32, 16)   2320        activation[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 32, 32, 16)   64          conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 32, 32, 16)   0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 32, 32, 16)   2320        activation_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 32, 32, 16)   64          conv2d_2[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 32, 32, 16)   0           activation[0][0]
#                                                                  batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 32, 32, 16)   0           add[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 32, 32, 16)   2320        activation_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 32, 32, 16)   64          conv2d_3[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 32, 32, 16)   0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 32, 32, 16)   2320        activation_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 32, 32, 16)   64          conv2d_4[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 32, 32, 16)   0           activation_2[0][0]
#                                                                  batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 32, 32, 16)   0           add_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 16, 16, 32)   4640        activation_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 16, 16, 32)   128         conv2d_5[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 16, 16, 32)   0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 16, 16, 32)   9248        activation_5[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 16, 16, 32)   544         activation_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 16, 16, 32)   128         conv2d_6[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 16, 16, 32)   0           conv2d_7[0][0]
#                                                                  batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 16, 16, 32)   0           add_2[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 16, 16, 32)   9248        activation_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 16, 16, 32)   128         conv2d_8[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 16, 16, 32)   0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 16, 16, 32)   9248        activation_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 16, 16, 32)   128         conv2d_9[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 16, 16, 32)   0           activation_6[0][0]
#                                                                  batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 16, 16, 32)   0           add_3[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 8, 8, 64)     18496       activation_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 8, 8, 64)     256         conv2d_10[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 8, 8, 64)     0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 8, 8, 64)     36928       activation_9[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 8, 8, 64)     2112        activation_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 8, 8, 64)     256         conv2d_11[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 8, 8, 64)     0           conv2d_12[0][0]
#                                                                  batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 8, 8, 64)     0           add_4[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 8, 8, 64)     36928       activation_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 8, 8, 64)     256         conv2d_13[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 8, 8, 64)     0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 8, 8, 64)     36928       activation_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 8, 8, 64)     256         conv2d_14[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 8, 8, 64)     0           activation_10[0][0]
#                                                                  batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 8, 8, 64)     0           add_5[0][0]
# __________________________________________________________________________________________________
# average_pooling2d (AveragePooli (None, 1, 1, 64)     0           activation_12[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 64)           0           average_pooling2d[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 10)           650         flatten[0][0]
# ==================================================================================================
# Total params: 176,554
# Trainable params: 175,626
# Non-trainable params: 928
# __________________________________________________________________________________________________
# ResNet14v1
# Using real-time data augmentation.
# WARNING:tensorflow:From <ipython-input-1-8823868c615d>:325: Model.fit_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.fit, which supports generators.
# Learning rate:  0.001
# Epoch 1/200
# 1562/1563 [============================>.] - ETA: 0s - loss: 1.5159 - accuracy: 0.4902WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 1563/1563 [==============================] - 37s 24ms/step - loss: 1.5159 - accuracy: 0.4902 - val_loss: 1.7146 - val_accuracy: 0.4726
# Learning rate:  0.001
# Epoch 2/200
# 1561/1563 [============================>.] - ETA: 0s - loss: 1.1540 - accuracy: 0.6327WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 1563/1563 [==============================] - 36s 23ms/step - loss: 1.1539 - accuracy: 0.6327 - val_loss: 1.1114 - val_accuracy: 0.6460
# Learning rate:  0.001
# Epoch 3/200
# 1563/1563 [==============================] - ETA: 0s - loss: 0.9988 - accuracy: 0.6914WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 1563/1563 [==============================] - 36s 23ms/step - loss: 0.9988 - accuracy: 0.6914 - val_loss: 1.1065 - val_accuracy: 0.6659
# Learning rate:  0.001
# Epoch 4/200
# 1563/1563 [==============================] - ETA: 0s - loss: 0.9014 - accuracy: 0.7307WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 1563/1563 [==============================] - 36s 23ms/step - loss: 0.9014 - accuracy: 0.7307 - val_loss: 1.1934 - val_accuracy: 0.6422
# Learning rate:  0.001
# Epoch 5/200
# 1562/1563 [============================>.] - ETA: 0s - loss: 0.8448 - accuracy: 0.7518WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 1563/1563 [==============================] - 36s 23ms/step - loss: 0.8447 - accuracy: 0.7519 - val_loss: 0.9088 - val_accuracy: 0.7354
# Learning rate:  0.001
# Epoch 6/200
# 1560/1563 [============================>.] - ETA: 0s - loss: 0.8010 - accuracy: 0.7696WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 1563/1563 [==============================] - 37s 24ms/step - loss: 0.8008 - accuracy: 0.7696 - val_loss: 0.7826 - val_accuracy: 0.7781
# Learning rate:  0.001
# Epoch 7/200
# 1562/1563 [============================>.] - ETA: 0s - loss: 0.7649 - accuracy: 0.7845WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 1563/1563 [==============================] - 36s 23ms/step - loss: 0.7648 - accuracy: 0.7846 - val_loss: 0.8256 - val_accuracy: 0.7715
# Learning rate:  0.001
# Epoch 8/200
# 1562/1563 [============================>.] - ETA: 0s - loss: 0.7412 - accuracy: 0.7929WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 1563/1563 [==============================] - 36s 23ms/step - loss: 0.7411 - accuracy: 0.7930 - val_loss: 0.7508 - val_accuracy: 0.7877
# Learning rate:  0.001
# Epoch 9/200
# 1563/1563 [==============================] - ETA: 0s - loss: 0.7167 - accuracy: 0.8024WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 1563/1563 [==============================] - 36s 23ms/step - loss: 0.7167 - accuracy: 0.8024 - val_loss: 0.8836 - val_accuracy: 0.7589
# Learning rate:  0.001
# Epoch 10/200
# 1560/1563 [============================>.] - ETA: 0s - loss: 0.6940 - accuracy: 0.8112WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 1563/1563 [==============================] - 36s 23ms/step - loss: 0.6943 - accuracy: 0.8112 - val_loss: 0.9921 - val_accuracy: 0.7225
# Learning rate:  0.001
# Epoch 11/200
# 1562/1563 [============================>.] - ETA: 0s - loss: 0.6747 - accuracy: 0.8204WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 1563/1563 [==============================] - 36s 23ms/step - loss: 0.6746 - accuracy: 0.8205 - val_loss: 0.9097 - val_accuracy: 0.7534
# Learning rate:  0.001
# Epoch 12/200
# 1563/1563 [==============================] - ETA: 0s - loss: 0.6637 - accuracy: 0.8239WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 1563/1563 [==============================] - 36s 23ms/step - loss: 0.6637 - accuracy: 0.8239 - val_loss: 0.8160 - val_accuracy: 0.7780
# Learning rate:  0.001
# Epoch 13/200
# 1563/1563 [==============================] - ETA: 0s - loss: 0.6455 - accuracy: 0.8311WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 1563/1563 [==============================] - 36s 23ms/step - loss: 0.6455 - accuracy: 0.8311 - val_loss: 1.0285 - val_accuracy: 0.7429
# Learning rate:  0.001
# Epoch 14/200
# 1560/1563 [============================>.] - ETA: 0s - loss: 0.6398 - accuracy: 0.8343WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 1563/1563 [==============================] - 35s 23ms/step - loss: 0.6399 - accuracy: 0.8342 - val_loss: 0.7229 - val_accuracy: 0.8129
# Learning rate:  0.001
# Epoch 15/200
# 1560/1563 [============================>.] - ETA: 0s - loss: 0.6340 - accuracy: 0.8356WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 1563/1563 [==============================] - 35s 23ms/step - loss: 0.6338 - accuracy: 0.8357 - val_loss: 0.7710 - val_accuracy: 0.8000
# Learning rate:  0.001
# Epoch 16/200
# 1560/1563 [============================>.] - ETA: 0s - loss: 0.6191 - accuracy: 0.8425WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 1563/1563 [==============================] - 35s 23ms/step - loss: 0.6189 - accuracy: 0.8426 - val_loss: 0.9324 - val_accuracy: 0.7618
# Learning rate:  0.001
# Epoch 17/200
# 1559/1563 [============================>.] - ETA: 0s - loss: 0.6155 - accuracy: 0.8439WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 1563/1563 [==============================] - 35s 23ms/step - loss: 0.6156 - accuracy: 0.8439 - val_loss: 0.8053 - val_accuracy: 0.7865
# Learning rate:  0.001
# Epoch 18/200
# 1562/1563 [============================>.] - ETA: 0s - loss: 0.6104 - accuracy: 0.8453WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 1563/1563 [==============================] - 35s 23ms/step - loss: 0.6103 - accuracy: 0.8454 - val_loss: 0.7204 - val_accuracy: 0.8127
# Learning rate:  0.001
# Epoch 19/200
# 1563/1563 [==============================] - ETA: 0s - loss: 0.6024 - accuracy: 0.8480WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 1563/1563 [==============================] - 36s 23ms/step - loss: 0.6024 - accuracy: 0.8480 - val_loss: 0.7856 - val_accuracy: 0.8044
# Learning rate:  0.001
# Epoch 20/200
# 1563/1563 [==============================] - ETA: 0s - loss: 0.5930 - accuracy: 0.8519WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 1563/1563 [==============================] - 35s 22ms/step - loss: 0.5930 - accuracy: 0.8519 - val_loss: 0.7296 - val_accuracy: 0.8164
# Learning rate:  0.001
# Epoch 21/200
# 1562/1563 [============================>.] - ETA: 0s - loss: 0.5863 - accuracy: 0.8537WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 1563/1563 [==============================] - 35s 23ms/step - loss: 0.5864 - accuracy: 0.8536 - val_loss: 0.7535 - val_accuracy: 0.8092
# Learning rate:  0.001
# Epoch 22/200
# 1563/1563 [==============================] - ETA: 0s - loss: 0.5839 - accuracy: 0.8561WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 1563/1563 [==============================] - 35s 22ms/step - loss: 0.5839 - accuracy: 0.8561 - val_loss: 0.7495 - val_accuracy: 0.8164
# Learning rate:  0.001
# Epoch 23/200
# 1560/1563 [============================>.] - ETA: 0s - loss: 0.5801 - accuracy: 0.8582WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 1563/1563 [==============================] - 35s 22ms/step - loss: 0.5799 - accuracy: 0.8582 - val_loss: 0.7243 - val_accuracy: 0.8193
# Learning rate:  0.001
# Epoch 24/200
# 1561/1563 [============================>.] - ETA: 0s - loss: 0.5721 - accuracy: 0.8629WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 1563/1563 [==============================] - 35s 22ms/step - loss: 0.5723 - accuracy: 0.8628 - val_loss: 0.8087 - val_accuracy: 0.8003
# Learning rate:  0.001
# Epoch 25/200
# 1562/1563 [============================>.] - ETA: 0s - loss: 0.5720 - accuracy: 0.8615WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 1563/1563 [==============================] - 35s 22ms/step - loss: 0.5720 - accuracy: 0.8615 - val_loss: 0.7425 - val_accuracy: 0.8113
# Learning rate:  0.001
# Epoch 26/200
# 1560/1563 [============================>.] - ETA: 0s - loss: 0.5689 - accuracy: 0.8631WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 1563/1563 [==============================] - 35s 22ms/step - loss: 0.5688 - accuracy: 0.8631 - val_loss: 0.8366 - val_accuracy: 0.7912
# Learning rate:  0.001
# Epoch 27/200
# 1563/1563 [==============================] - ETA: 0s - loss: 0.5656 - accuracy: 0.8628WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 1563/1563 [==============================] - 35s 23ms/step - loss: 0.5656 - accuracy: 0.8628 - val_loss: 1.0471 - val_accuracy: 0.7221
# Learning rate:  0.001
# Epoch 28/200
# 1562/1563 [============================>.] - ETA: 0s - loss: 0.5570 - accuracy: 0.8691WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 1563/1563 [==============================] - 34s 22ms/step - loss: 0.5569 - accuracy: 0.8691 - val_loss: 0.7237 - val_accuracy: 0.8178
# Learning rate:  0.001
# Epoch 29/200
# 1561/1563 [============================>.] - ETA: 0s - loss: 0.5647 - accuracy: 0.8641WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 1563/1563 [==============================] - 35s 22ms/step - loss: 0.5645 - accuracy: 0.8642 - val_loss: 0.8989 - val_accuracy: 0.7801
# Learning rate:  0.001
# Epoch 30/200
# 1561/1563 [============================>.] - ETA: 0s - loss: 0.5570 - accuracy: 0.8673WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 1563/1563 [==============================] - 35s 22ms/step - loss: 0.5571 - accuracy: 0.8672 - val_loss: 0.6467 - val_accuracy: 0.8424
# Learning rate:  0.001
# Epoch 31/200
# 1560/1563 [============================>.] - ETA: 0s - loss: 0.5537 - accuracy: 0.8687WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 1563/1563 [==============================] - 35s 22ms/step - loss: 0.5536 - accuracy: 0.8687 - val_loss: 0.7174 - val_accuracy: 0.8223
# Learning rate:  0.001
# Epoch 32/200
# 1561/1563 [============================>.] - ETA: 0s - loss: 0.5520 - accuracy: 0.8700WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 1563/1563 [==============================] - 34s 22ms/step - loss: 0.5519 - accuracy: 0.8701 - val_loss: 0.7847 - val_accuracy: 0.7964
# Learning rate:  0.001
# Epoch 33/200
# 1563/1563 [==============================] - ETA: 0s - loss: 0.5495 - accuracy: 0.8711WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 1563/1563 [==============================] - 35s 22ms/step - loss: 0.5495 - accuracy: 0.8711 - val_loss: 0.6796 - val_accuracy: 0.8313
# Learning rate:  0.001
# Epoch 34/200
# 1560/1563 [============================>.] - ETA: 0s - loss: 0.5472 - accuracy: 0.8735WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 1563/1563 [==============================] - 35s 22ms/step - loss: 0.5471 - accuracy: 0.8735 - val_loss: 0.7194 - val_accuracy: 0.8254
# Learning rate:  0.001
# Epoch 35/200
# 1563/1563 [==============================] - ETA: 0s - loss: 0.5454 - accuracy: 0.8731WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 1563/1563 [==============================] - 34s 22ms/step - loss: 0.5454 - accuracy: 0.8731 - val_loss: 0.6525 - val_accuracy: 0.8450
# Learning rate:  0.001
# Epoch 36/200
# 1562/1563 [============================>.] - ETA: 0s - loss: 0.5388 - accuracy: 0.8751WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 1563/1563 [==============================] - 35s 22ms/step - loss: 0.5387 - accuracy: 0.8752 - val_loss: 0.8504 - val_accuracy: 0.7970
# Learning rate:  0.001
# Epoch 37/200
# 1561/1563 [============================>.] - ETA: 0s - loss: 0.5375 - accuracy: 0.8761WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 1563/1563 [==============================] - 34s 22ms/step - loss: 0.5377 - accuracy: 0.8761 - val_loss: 0.7212 - val_accuracy: 0.8282
# Learning rate:  0.001
# Epoch 38/200
# 1562/1563 [============================>.] - ETA: 0s - loss: 0.5375 - accuracy: 0.8756WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 1563/1563 [==============================] - 35s 22ms/step - loss: 0.5374 - accuracy: 0.8756 - val_loss: 0.8684 - val_accuracy: 0.7905
# Learning rate:  0.001
# Epoch 39/200
# 1560/1563 [============================>.] - ETA: 0s - loss: 0.5355 - accuracy: 0.8755WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 1563/1563 [==============================] - 34s 22ms/step - loss: 0.5355 - accuracy: 0.8755 - val_loss: 0.6518 - val_accuracy: 0.8430
# Learning rate:  0.001
# Epoch 40/200
# 1562/1563 [============================>.] - ETA: 0s - loss: 0.5321 - accuracy: 0.8779WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 1563/1563 [==============================] - 34s 22ms/step - loss: 0.5320 - accuracy: 0.8779 - val_loss: 0.7402 - val_accuracy: 0.8189
# Learning rate:  0.001
# Epoch 41/200
# 1562/1563 [============================>.] - ETA: 0s - loss: 0.5308 - accuracy: 0.8786WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 1563/1563 [==============================] - 34s 22ms/step - loss: 0.5308 - accuracy: 0.8786 - val_loss: 0.6634 - val_accuracy: 0.8429
# Learning rate:  0.001
# Epoch 42/200
# 1560/1563 [============================>.] - ETA: 0s - loss: 0.5283 - accuracy: 0.8780WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 1563/1563 [==============================] - 34s 22ms/step - loss: 0.5283 - accuracy: 0.8779 - val_loss: 0.7197 - val_accuracy: 0.8274
# Learning rate:  0.001
# Epoch 43/200
# 1563/1563 [==============================] - ETA: 0s - loss: 0.5312 - accuracy: 0.8792WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 1563/1563 [==============================] - 34s 22ms/step - loss: 0.5312 - accuracy: 0.8792 - val_loss: 0.9076 - val_accuracy: 0.7846
# Learning rate:  0.001
# Epoch 44/200
# 1563/1563 [==============================] - ETA: 0s - loss: 0.5271 - accuracy: 0.8793WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 1563/1563 [==============================] - 34s 22ms/step - loss: 0.5271 - accuracy: 0.8793 - val_loss: 0.6906 - val_accuracy: 0.8432
# Learning rate:  0.001
# Epoch 45/200
# 1563/1563 [==============================] - ETA: 0s - loss: 0.5263 - accuracy: 0.8797WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 1563/1563 [==============================] - 35s 22ms/step - loss: 0.5263 - accuracy: 0.8797 - val_loss: 0.7555 - val_accuracy: 0.8149
# Learning rate:  0.001
# Epoch 46/200
# 1559/1563 [============================>.] - ETA: 0s - loss: 0.5233 - accuracy: 0.8806WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 1563/1563 [==============================] - 34s 22ms/step - loss: 0.5234 - accuracy: 0.8804 - val_loss: 0.6451 - val_accuracy: 0.8465
# Learning rate:  0.001
# Epoch 47/200
# 1561/1563 [============================>.] - ETA: 0s - loss: 0.5222 - accuracy: 0.8823WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 1563/1563 [==============================] - 34s 22ms/step - loss: 0.5225 - accuracy: 0.8822 - val_loss: 0.7022 - val_accuracy: 0.8352
# Learning rate:  0.001
# Epoch 48/200
# 1560/1563 [============================>.] - ETA: 0s - loss: 0.5193 - accuracy: 0.8829WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 1563/1563 [==============================] - 34s 22ms/step - loss: 0.5194 - accuracy: 0.8828 - val_loss: 0.6469 - val_accuracy: 0.8470
# Learning rate:  0.001
# Epoch 49/200
# 1560/1563 [============================>.] - ETA: 0s - loss: 0.5147 - accuracy: 0.8847WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 1563/1563 [==============================] - 34s 22ms/step - loss: 0.5149 - accuracy: 0.8845 - val_loss: 0.6945 - val_accuracy: 0.8348
# Learning rate:  0.001
# Epoch 50/200
# 1561/1563 [============================>.] - ETA: 0s - loss: 0.5197 - accuracy: 0.8831WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 1563/1563 [==============================] - 34s 22ms/step - loss: 0.5196 - accuracy: 0.8831 - val_loss: 0.6447 - val_accuracy: 0.8473
# Learning rate:  0.001
# Epoch 51/200
# 1561/1563 [============================>.] - ETA: 0s - loss: 0.5179 - accuracy: 0.8838WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 1563/1563 [==============================] - 34s 22ms/step - loss: 0.5177 - accuracy: 0.8839 - val_loss: 0.8467 - val_accuracy: 0.7966
# Learning rate:  0.001
# Epoch 52/200
# 1559/1563 [============================>.] - ETA: 0s - loss: 0.5159 - accuracy: 0.8836WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 1563/1563 [==============================] - 35s 22ms/step - loss: 0.5161 - accuracy: 0.8837 - val_loss: 0.7196 - val_accuracy: 0.8290
# Learning rate:  0.001
# Epoch 53/200
# 1560/1563 [============================>.] - ETA: 0s - loss: 0.5178 - accuracy: 0.8828WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 1563/1563 [==============================] - 35s 22ms/step - loss: 0.5178 - accuracy: 0.8828 - val_loss: 0.8418 - val_accuracy: 0.8010
# Learning rate:  0.001
# Epoch 54/200
# 1560/1563 [============================>.] - ETA: 0s - loss: 0.5104 - accuracy: 0.8860WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 1563/1563 [==============================] - 37s 23ms/step - loss: 0.5105 - accuracy: 0.8860 - val_loss: 0.6848 - val_accuracy: 0.8386
# Learning rate:  0.001
# Epoch 55/200
# 1560/1563 [============================>.] - ETA: 0s - loss: 0.5136 - accuracy: 0.8853WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 1563/1563 [==============================] - 36s 23ms/step - loss: 0.5134 - accuracy: 0.8853 - val_loss: 0.7430 - val_accuracy: 0.8224
# Learning rate:  0.001
# Epoch 56/200
# 1560/1563 [============================>.] - ETA: 0s - loss: 0.5095 - accuracy: 0.8874WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 1563/1563 [==============================] - 35s 23ms/step - loss: 0.5094 - accuracy: 0.8874 - val_loss: 0.6585 - val_accuracy: 0.8453
# Learning rate:  0.001
# Epoch 57/200
# 1560/1563 [============================>.] - ETA: 0s - loss: 0.5100 - accuracy: 0.8868WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 1563/1563 [==============================] - 35s 23ms/step - loss: 0.5100 - accuracy: 0.8869 - val_loss: 0.6616 - val_accuracy: 0.8411
# Learning rate:  0.001
# Epoch 58/200
# 1562/1563 [============================>.] - ETA: 0s - loss: 0.5154 - accuracy: 0.8845WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 1563/1563 [==============================] - 35s 22ms/step - loss: 0.5154 - accuracy: 0.8845 - val_loss: 0.7844 - val_accuracy: 0.8146
# Learning rate:  0.001
# Epoch 59/200
# 1563/1563 [==============================] - ETA: 0s - loss: 0.5066 - accuracy: 0.8874WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 1563/1563 [==============================] - 35s 22ms/step - loss: 0.5066 - accuracy: 0.8874 - val_loss: 0.6661 - val_accuracy: 0.8446
# Learning rate:  0.001
# Epoch 60/200
# 1561/1563 [============================>.] - ETA: 0s - loss: 0.5081 - accuracy: 0.8881WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 1563/1563 [==============================] - 35s 22ms/step - loss: 0.5083 - accuracy: 0.8881 - val_loss: 0.7909 - val_accuracy: 0.8171
# Learning rate:  0.001
# Epoch 61/200
# 1561/1563 [============================>.] - ETA: 0s - loss: 0.5056 - accuracy: 0.8888WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 1563/1563 [==============================] - 35s 23ms/step - loss: 0.5056 - accuracy: 0.8888 - val_loss: 0.6891 - val_accuracy: 0.8419
# Learning rate:  0.001
# Epoch 62/200
# 1562/1563 [============================>.] - ETA: 0s - loss: 0.5068 - accuracy: 0.8883WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 1563/1563 [==============================] - 35s 22ms/step - loss: 0.5069 - accuracy: 0.8883 - val_loss: 0.8958 - val_accuracy: 0.7833
# Learning rate:  0.001
# Epoch 63/200
# 1562/1563 [============================>.] - ETA: 0s - loss: 0.5048 - accuracy: 0.8892WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 1563/1563 [==============================] - 35s 23ms/step - loss: 0.5050 - accuracy: 0.8891 - val_loss: 0.6646 - val_accuracy: 0.8435
# Learning rate:  0.001
# Epoch 64/200
# 1561/1563 [============================>.] - ETA: 0s - loss: 0.5073 - accuracy: 0.8892WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 1563/1563 [==============================] - 35s 23ms/step - loss: 0.5072 - accuracy: 0.8893 - val_loss: 0.6909 - val_accuracy: 0.8327
# Learning rate:  0.001
# Epoch 65/200
# 1562/1563 [============================>.] - ETA: 0s - loss: 0.4999 - accuracy: 0.8896WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 1563/1563 [==============================] - 35s 22ms/step - loss: 0.4998 - accuracy: 0.8896 - val_loss: 0.6096 - val_accuracy: 0.8602
# Learning rate:  0.001
# Epoch 66/200
# 1559/1563 [============================>.] - ETA: 0s - loss: 0.4977 - accuracy: 0.8905WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 1563/1563 [==============================] - 35s 23ms/step - loss: 0.4976 - accuracy: 0.8905 - val_loss: 0.6846 - val_accuracy: 0.8435
# Learning rate:  0.001
# Epoch 67/200
# 1559/1563 [============================>.] - ETA: 0s - loss: 0.4995 - accuracy: 0.8897WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 1563/1563 [==============================] - 35s 23ms/step - loss: 0.4996 - accuracy: 0.8897 - val_loss: 0.7198 - val_accuracy: 0.8351
# Learning rate:  0.001
# Epoch 68/200
# 1561/1563 [============================>.] - ETA: 0s - loss: 0.4970 - accuracy: 0.8916WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 1563/1563 [==============================] - 35s 23ms/step - loss: 0.4970 - accuracy: 0.8916 - val_loss: 0.7460 - val_accuracy: 0.8264
# Learning rate:  0.001
# Epoch 69/200
# 1560/1563 [============================>.] - ETA: 0s - loss: 0.4989 - accuracy: 0.8918WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 1563/1563 [==============================] - 35s 22ms/step - loss: 0.4989 - accuracy: 0.8918 - val_loss: 0.6934 - val_accuracy: 0.8357
# Learning rate:  0.001
# Epoch 70/200
# 1560/1563 [============================>.] - ETA: 0s - loss: 0.4957 - accuracy: 0.8914WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 1563/1563 [==============================] - 35s 23ms/step - loss: 0.4956 - accuracy: 0.8914 - val_loss: 0.7280 - val_accuracy: 0.8206
# Learning rate:  0.001
# Epoch 71/200
# 1562/1563 [============================>.] - ETA: 0s - loss: 0.4936 - accuracy: 0.8933WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 1563/1563 [==============================] - 35s 23ms/step - loss: 0.4936 - accuracy: 0.8933 - val_loss: 0.7404 - val_accuracy: 0.8291
# Learning rate:  0.001
# Epoch 72/200
# 1560/1563 [============================>.] - ETA: 0s - loss: 0.4917 - accuracy: 0.8932WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 1563/1563 [==============================] - 36s 23ms/step - loss: 0.4918 - accuracy: 0.8931 - val_loss: 0.6185 - val_accuracy: 0.8606
# Learning rate:  0.001
# Epoch 73/200
# 1563/1563 [==============================] - ETA: 0s - loss: 0.4940 - accuracy: 0.8924WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 1563/1563 [==============================] - 36s 23ms/step - loss: 0.4940 - accuracy: 0.8924 - val_loss: 0.7462 - val_accuracy: 0.8189
# Learning rate:  0.001
# Epoch 74/200
# 1563/1563 [==============================] - ETA: 0s - loss: 0.4964 - accuracy: 0.8923WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 1563/1563 [==============================] - 35s 23ms/step - loss: 0.4964 - accuracy: 0.8923 - val_loss: 0.6782 - val_accuracy: 0.8417
# Learning rate:  0.001
# Epoch 75/200
# 1562/1563 [============================>.] - ETA: 0s - loss: 0.4953 - accuracy: 0.8924WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 1563/1563 [==============================] - 36s 23ms/step - loss: 0.4953 - accuracy: 0.8924 - val_loss: 0.6593 - val_accuracy: 0.8470
# Learning rate:  0.001
# Epoch 76/200
# 1561/1563 [============================>.] - ETA: 0s - loss: 0.4932 - accuracy: 0.8936WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 1563/1563 [==============================] - 35s 23ms/step - loss: 0.4933 - accuracy: 0.8936 - val_loss: 0.6734 - val_accuracy: 0.8466
# Learning rate:  0.001
# Epoch 77/200
# 1561/1563 [============================>.] - ETA: 0s - loss: 0.4941 - accuracy: 0.8917WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 1563/1563 [==============================] - 35s 23ms/step - loss: 0.4941 - accuracy: 0.8917 - val_loss: 0.6484 - val_accuracy: 0.8495
# Learning rate:  0.001
# Epoch 78/200
# 1561/1563 [============================>.] - ETA: 0s - loss: 0.4876 - accuracy: 0.8940WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 1563/1563 [==============================] - 35s 23ms/step - loss: 0.4878 - accuracy: 0.8940 - val_loss: 0.6614 - val_accuracy: 0.8485
# Learning rate:  0.001
# Epoch 79/200
# 1560/1563 [============================>.] - ETA: 0s - loss: 0.4892 - accuracy: 0.8956WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 1563/1563 [==============================] - 34s 22ms/step - loss: 0.4892 - accuracy: 0.8956 - val_loss: 0.6722 - val_accuracy: 0.8424
# Learning rate:  0.001
# Epoch 80/200
# 1561/1563 [============================>.] - ETA: 0s - loss: 0.4844 - accuracy: 0.8963WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 1563/1563 [==============================] - 35s 22ms/step - loss: 0.4844 - accuracy: 0.8963 - val_loss: 0.7963 - val_accuracy: 0.8187
# Learning rate:  0.001
# Epoch 81/200
# 1563/1563 [==============================] - ETA: 0s - loss: 0.4855 - accuracy: 0.8957WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 1563/1563 [==============================] - 37s 23ms/step - loss: 0.4855 - accuracy: 0.8957 - val_loss: 0.6961 - val_accuracy: 0.8344
# Learning rate:  0.0001
# Epoch 82/200
# 1560/1563 [============================>.] - ETA: 0s - loss: 0.4157 - accuracy: 0.9203WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 1563/1563 [==============================] - 37s 23ms/step - loss: 0.4156 - accuracy: 0.9203 - val_loss: 0.4888 - val_accuracy: 0.8962
# Learning rate:  0.0001
# Epoch 83/200
# 1563/1563 [==============================] - ETA: 0s - loss: 0.3839 - accuracy: 0.9302WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 1563/1563 [==============================] - 37s 23ms/step - loss: 0.3839 - accuracy: 0.9302 - val_loss: 0.4892 - val_accuracy: 0.8938
# Learning rate:  0.0001
# Epoch 84/200
# 1560/1563 [============================>.] - ETA: 0s - loss: 0.3733 - accuracy: 0.9314WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 1563/1563 [==============================] - 36s 23ms/step - loss: 0.3734 - accuracy: 0.9314 - val_loss: 0.4813 - val_accuracy: 0.8975
# Learning rate:  0.0001
# Epoch 85/200
# 1562/1563 [============================>.] - ETA: 0s - loss: 0.3534 - accuracy: 0.9383WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 1563/1563 [==============================] - 35s 22ms/step - loss: 0.3534 - accuracy: 0.9383 - val_loss: 0.4898 - val_accuracy: 0.8973
# Learning rate:  0.0001
# Epoch 86/200
# 1560/1563 [============================>.] - ETA: 0s - loss: 0.3477 - accuracy: 0.9395WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 1563/1563 [==============================] - 36s 23ms/step - loss: 0.3477 - accuracy: 0.9395 - val_loss: 0.4737 - val_accuracy: 0.9005
# Learning rate:  0.0001
# Epoch 87/200
# 1561/1563 [============================>.] - ETA: 0s - loss: 0.3426 - accuracy: 0.9412WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 1563/1563 [==============================] - 35s 22ms/step - loss: 0.3425 - accuracy: 0.9413 - val_loss: 0.4684 - val_accuracy: 0.9027
# Learning rate:  0.0001
# Epoch 88/200
# 1561/1563 [============================>.] - ETA: 0s - loss: 0.3352 - accuracy: 0.9424WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 1563/1563 [==============================] - 35s 22ms/step - loss: 0.3352 - accuracy: 0.9424 - val_loss: 0.4775 - val_accuracy: 0.8994
# Learning rate:  0.0001
# Epoch 89/200
# 1560/1563 [============================>.] - ETA: 0s - loss: 0.3292 - accuracy: 0.9444WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 1563/1563 [==============================] - 36s 23ms/step - loss: 0.3292 - accuracy: 0.9444 - val_loss: 0.4788 - val_accuracy: 0.8984
# Learning rate:  0.0001
# Epoch 90/200
# 1561/1563 [============================>.] - ETA: 0s - loss: 0.3243 - accuracy: 0.9445WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 1563/1563 [==============================] - 35s 23ms/step - loss: 0.3243 - accuracy: 0.9446 - val_loss: 0.4609 - val_accuracy: 0.9046
# Learning rate:  0.0001
# Epoch 91/200
# 1560/1563 [============================>.] - ETA: 0s - loss: 0.3187 - accuracy: 0.9450WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 1563/1563 [==============================] - 35s 23ms/step - loss: 0.3186 - accuracy: 0.9450 - val_loss: 0.4713 - val_accuracy: 0.9007
# Learning rate:  0.0001
# Epoch 92/200
# 1559/1563 [============================>.] - ETA: 0s - loss: 0.3158 - accuracy: 0.9456WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 1563/1563 [==============================] - 35s 22ms/step - loss: 0.3158 - accuracy: 0.9456 - val_loss: 0.4558 - val_accuracy: 0.9052
# Learning rate:  0.0001
# Epoch 93/200
# 1562/1563 [============================>.] - ETA: 0s - loss: 0.3096 - accuracy: 0.9479WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 1563/1563 [==============================] - 35s 23ms/step - loss: 0.3097 - accuracy: 0.9479 - val_loss: 0.4683 - val_accuracy: 0.9021
# Learning rate:  0.0001
# Epoch 94/200
# 1562/1563 [============================>.] - ETA: 0s - loss: 0.3046 - accuracy: 0.9478WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 1563/1563 [==============================] - 35s 23ms/step - loss: 0.3046 - accuracy: 0.9478 - val_loss: 0.4587 - val_accuracy: 0.9035
# Learning rate:  0.0001
# Epoch 95/200
# 1563/1563 [==============================] - ETA: 0s - loss: 0.3029 - accuracy: 0.9489WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 1563/1563 [==============================] - 35s 23ms/step - loss: 0.3029 - accuracy: 0.9489 - val_loss: 0.4596 - val_accuracy: 0.9027
# Learning rate:  0.0001
# Epoch 96/200
# 1560/1563 [============================>.] - ETA: 0s - loss: 0.2997 - accuracy: 0.9482WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 1563/1563 [==============================] - 35s 23ms/step - loss: 0.2997 - accuracy: 0.9482 - val_loss: 0.4517 - val_accuracy: 0.9044
# Learning rate:  0.0001
# Epoch 97/200
# 1560/1563 [============================>.] - ETA: 0s - loss: 0.2937 - accuracy: 0.9496WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 1563/1563 [==============================] - 35s 23ms/step - loss: 0.2937 - accuracy: 0.9496 - val_loss: 0.4563 - val_accuracy: 0.9040
# Learning rate:  0.0001
# Epoch 98/200
# 1561/1563 [============================>.] - ETA: 0s - loss: 0.2921 - accuracy: 0.9503WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 1563/1563 [==============================] - 36s 23ms/step - loss: 0.2919 - accuracy: 0.9503 - val_loss: 0.4624 - val_accuracy: 0.9008
# Learning rate:  0.0001
# Epoch 99/200
# 1563/1563 [==============================] - ETA: 0s - loss: 0.2864 - accuracy: 0.9513WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 1563/1563 [==============================] - 35s 23ms/step - loss: 0.2864 - accuracy: 0.9513 - val_loss: 0.4587 - val_accuracy: 0.9033
# Learning rate:  0.0001
# Epoch 100/200
# 1562/1563 [============================>.] - ETA: 0s - loss: 0.2832 - accuracy: 0.9521WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 1563/1563 [==============================] - 35s 23ms/step - loss: 0.2831 - accuracy: 0.9522 - val_loss: 0.4547 - val_accuracy: 0.9018
# Learning rate:  0.0001
# Epoch 101/200
# 1562/1563 [============================>.] - ETA: 0s - loss: 0.2793 - accuracy: 0.9529WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 1563/1563 [==============================] - 35s 22ms/step - loss: 0.2793 - accuracy: 0.9529 - val_loss: 0.4557 - val_accuracy: 0.9023
# Learning rate:  0.0001
# Epoch 102/200
# 1560/1563 [============================>.] - ETA: 0s - loss: 0.2788 - accuracy: 0.9530WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 1563/1563 [==============================] - 35s 22ms/step - loss: 0.2790 - accuracy: 0.9530 - val_loss: 0.4513 - val_accuracy: 0.9031
# Learning rate:  0.0001
# Epoch 103/200
# 1560/1563 [============================>.] - ETA: 0s - loss: 0.2776 - accuracy: 0.9526WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 1563/1563 [==============================] - 35s 22ms/step - loss: 0.2774 - accuracy: 0.9527 - val_loss: 0.4614 - val_accuracy: 0.9000
# Learning rate:  0.0001
# Epoch 104/200
# 1562/1563 [============================>.] - ETA: 0s - loss: 0.2720 - accuracy: 0.9542WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 1563/1563 [==============================] - 35s 22ms/step - loss: 0.2720 - accuracy: 0.9542 - val_loss: 0.4505 - val_accuracy: 0.9032
# Learning rate:  0.0001
# Epoch 105/200
# 1561/1563 [============================>.] - ETA: 0s - loss: 0.2686 - accuracy: 0.9543WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 1563/1563 [==============================] - 34s 22ms/step - loss: 0.2686 - accuracy: 0.9543 - val_loss: 0.4469 - val_accuracy: 0.9060
# Learning rate:  0.0001
# Epoch 106/200
# 1561/1563 [============================>.] - ETA: 0s - loss: 0.2680 - accuracy: 0.9543WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 1563/1563 [==============================] - 35s 22ms/step - loss: 0.2680 - accuracy: 0.9543 - val_loss: 0.4550 - val_accuracy: 0.9025
# Learning rate:  0.0001
# Epoch 107/200
# 1560/1563 [============================>.] - ETA: 0s - loss: 0.2627 - accuracy: 0.9548WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 1563/1563 [==============================] - 35s 23ms/step - loss: 0.2626 - accuracy: 0.9548 - val_loss: 0.4563 - val_accuracy: 0.9025
# Learning rate:  0.0001
# Epoch 108/200
# 1561/1563 [============================>.] - ETA: 0s - loss: 0.2647 - accuracy: 0.9551WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 1563/1563 [==============================] - 35s 22ms/step - loss: 0.2649 - accuracy: 0.9551 - val_loss: 0.4578 - val_accuracy: 0.9021
# Learning rate:  0.0001
# Epoch 109/200
# ...
# Learning rate:  1e-05
# Epoch 154/200
# 1563/1563 [==============================] - ETA: 0s - loss: 0.2083 - accuracy: 0.9692WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 1563/1563 [==============================] - 34s 22ms/step - loss: 0.2083 - accuracy: 0.9692 - val_loss: 0.4323 - val_accuracy: 0.9077
# Learning rate:  1e-05
# Epoch 155/200
# 1559/1563 [============================>.] - ETA: 0s - loss: 0.2080 - accuracy: 0.9688WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 1563/1563 [==============================] - 34s 22ms/step - loss: 0.2080 - accuracy: 0.9688 - val_loss: 0.4339 - val_accuracy: 0.9062
# Learning rate:  1e-05
# Epoch 156/200
# 1560/1563 [============================>.] - ETA: 0s - loss: 0.2101 - accuracy: 0.9681WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 1563/1563 [==============================] - 34s 22ms/step - loss: 0.2101 - accuracy: 0.9681 - val_loss: 0.4362 - val_accuracy: 0.9059
# Learning rate:  1e-05
# Epoch 157/200
# 1560/1563 [============================>.] - ETA: 0s - loss: 0.2062 - accuracy: 0.9685WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 1563/1563 [==============================] - 34s 22ms/step - loss: 0.2062 - accuracy: 0.9685 - val_loss: 0.4358 - val_accuracy: 0.9069
# Learning rate:  1e-05
# Epoch 158/200
# 1563/1563 [==============================] - ETA: 0s - loss: 0.2081 - accuracy: 0.9695WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 1563/1563 [==============================] - 34s 22ms/step - loss: 0.2081 - accuracy: 0.9695 - val_loss: 0.4357 - val_accuracy: 0.9068
# Learning rate:  1e-05
# Epoch 159/200
# 1562/1563 [============================>.] - ETA: 0s - loss: 0.2049 - accuracy: 0.9704WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 1563/1563 [==============================] - 34s 22ms/step - loss: 0.2050 - accuracy: 0.9704 - val_loss: 0.4356 - val_accuracy: 0.9064
# Learning rate:  1e-05
# Epoch 160/200
# 1560/1563 [============================>.] - ETA: 0s - loss: 0.2083 - accuracy: 0.9686WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 1563/1563 [==============================] - 35s 22ms/step - loss: 0.2082 - accuracy: 0.9686 - val_loss: 0.4324 - val_accuracy: 0.9076
# Learning rate:  1e-05
# Epoch 161/200
# 1563/1563 [==============================] - ETA: 0s - loss: 0.2062 - accuracy: 0.9692WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 1563/1563 [==============================] - 34s 22ms/step - loss: 0.2062 - accuracy: 0.9692 - val_loss: 0.4372 - val_accuracy: 0.9057
# Learning rate:  1e-06
# Epoch 162/200
# 1560/1563 [============================>.] - ETA: 0s - loss: 0.2051 - accuracy: 0.9704WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 1563/1563 [==============================] - 34s 22ms/step - loss: 0.2050 - accuracy: 0.9704 - val_loss: 0.4349 - val_accuracy: 0.9058
# Learning rate:  1e-06
# Epoch 163/200
# 1561/1563 [============================>.] - ETA: 0s - loss: 0.2042 - accuracy: 0.9703WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 1563/1563 [==============================] - 34s 22ms/step - loss: 0.2042 - accuracy: 0.9703 - val_loss: 0.4365 - val_accuracy: 0.9053
# Learning rate:  1e-06
# Epoch 164/200
# 1563/1563 [==============================] - ETA: 0s - loss: 0.2045 - accuracy: 0.9702WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 1563/1563 [==============================] - 34s 22ms/step - loss: 0.2045 - accuracy: 0.9702 - val_loss: 0.4359 - val_accuracy: 0.9051
# Learning rate:  1e-06
# Epoch 165/200
# 1563/1563 [==============================] - ETA: 0s - loss: 0.2043 - accuracy: 0.9700WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 1563/1563 [==============================] - 34s 22ms/step - loss: 0.2043 - accuracy: 0.9700 - val_loss: 0.4378 - val_accuracy: 0.9055
# Learning rate:  1e-06
# Epoch 166/200
# 1561/1563 [============================>.] - ETA: 0s - loss: 0.2046 - accuracy: 0.9705WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 1563/1563 [==============================] - 34s 22ms/step - loss: 0.2046 - accuracy: 0.9705 - val_loss: 0.4359 - val_accuracy: 0.9058
# Learning rate:  1e-06
# Epoch 167/200
# 1559/1563 [============================>.] - ETA: 0s - loss: 0.2038 - accuracy: 0.9699WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 1563/1563 [==============================] - 34s 22ms/step - loss: 0.2036 - accuracy: 0.9699 - val_loss: 0.4332 - val_accuracy: 0.9068
# Learning rate:  1e-06
# Epoch 168/200
# 1560/1563 [============================>.] - ETA: 0s - loss: 0.2043 - accuracy: 0.9699WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 1563/1563 [==============================] - 34s 22ms/step - loss: 0.2043 - accuracy: 0.9699 - val_loss: 0.4362 - val_accuracy: 0.9059
# Learning rate:  1e-06
# Epoch 169/200
# 1562/1563 [============================>.] - ETA: 0s - loss: 0.2039 - accuracy: 0.9704WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 1563/1563 [==============================] - 35s 22ms/step - loss: 0.2039 - accuracy: 0.9704 - val_loss: 0.4355 - val_accuracy: 0.9055
# Learning rate:  1e-06
# Epoch 170/200
# 1563/1563 [==============================] - ETA: 0s - loss: 0.2047 - accuracy: 0.9699WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 1563/1563 [==============================] - 34s 22ms/step - loss: 0.2047 - accuracy: 0.9699 - val_loss: 0.4342 - val_accuracy: 0.9065
# Learning rate:  1e-06
# Epoch 171/200
# 1562/1563 [============================>.] - ETA: 0s - loss: 0.2047 - accuracy: 0.9693WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 1563/1563 [==============================] - 35s 22ms/step - loss: 0.2046 - accuracy: 0.9693 - val_loss: 0.4352 - val_accuracy: 0.9057
# Learning rate:  1e-06
# Epoch 172/200
# 1562/1563 [============================>.] - ETA: 0s - loss: 0.2078 - accuracy: 0.9687WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 1563/1563 [==============================] - 34s 22ms/step - loss: 0.2078 - accuracy: 0.9687 - val_loss: 0.4367 - val_accuracy: 0.9064
# Learning rate:  1e-06
# Epoch 173/200
# 1562/1563 [============================>.] - ETA: 0s - loss: 0.2044 - accuracy: 0.9694WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 1563/1563 [==============================] - 34s 22ms/step - loss: 0.2044 - accuracy: 0.9694 - val_loss: 0.4352 - val_accuracy: 0.9064
# Learning rate:  1e-06
# Epoch 174/200
# 1561/1563 [============================>.] - ETA: 0s - loss: 0.2061 - accuracy: 0.9693WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 1563/1563 [==============================] - 34s 22ms/step - loss: 0.2062 - accuracy: 0.9693 - val_loss: 0.4345 - val_accuracy: 0.9065
# Learning rate:  1e-06
# Epoch 175/200
# 1563/1563 [==============================] - ETA: 0s - loss: 0.2057 - accuracy: 0.9690WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 1563/1563 [==============================] - 34s 22ms/step - loss: 0.2057 - accuracy: 0.9690 - val_loss: 0.4352 - val_accuracy: 0.9058
# Learning rate:  1e-06
# Epoch 176/200
# 1563/1563 [==============================] - ETA: 0s - loss: 0.2031 - accuracy: 0.9702WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 1563/1563 [==============================] - 34s 22ms/step - loss: 0.2031 - accuracy: 0.9702 - val_loss: 0.4330 - val_accuracy: 0.9064
# Learning rate:  1e-06
# Epoch 177/200
# 1561/1563 [============================>.] - ETA: 0s - loss: 0.2030 - accuracy: 0.9709WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 1563/1563 [==============================] - 35s 22ms/step - loss: 0.2030 - accuracy: 0.9709 - val_loss: 0.4349 - val_accuracy: 0.9063
# Learning rate:  1e-06
# Epoch 178/200
# 1560/1563 [============================>.] - ETA: 0s - loss: 0.2020 - accuracy: 0.9710WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 1563/1563 [==============================] - 35s 22ms/step - loss: 0.2020 - accuracy: 0.9709 - val_loss: 0.4341 - val_accuracy: 0.9061
# Learning rate:  1e-06
# Epoch 179/200
# 1562/1563 [============================>.] - ETA: 0s - loss: 0.2045 - accuracy: 0.9705WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 1563/1563 [==============================] - 34s 22ms/step - loss: 0.2045 - accuracy: 0.9705 - val_loss: 0.4343 - val_accuracy: 0.9063
# Learning rate:  1e-06
# Epoch 180/200
# 1559/1563 [============================>.] - ETA: 0s - loss: 0.2040 - accuracy: 0.9706WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 1563/1563 [==============================] - 35s 22ms/step - loss: 0.2041 - accuracy: 0.9705 - val_loss: 0.4360 - val_accuracy: 0.9066
# Learning rate:  1e-06
# Epoch 181/200
# 1560/1563 [============================>.] - ETA: 0s - loss: 0.2023 - accuracy: 0.9712WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 1563/1563 [==============================] - 34s 22ms/step - loss: 0.2024 - accuracy: 0.9712 - val_loss: 0.4335 - val_accuracy: 0.9068
# Learning rate:  5e-07
# Epoch 182/200
# 1559/1563 [============================>.] - ETA: 0s - loss: 0.2025 - accuracy: 0.9704WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 1563/1563 [==============================] - 34s 22ms/step - loss: 0.2024 - accuracy: 0.9704 - val_loss: 0.4349 - val_accuracy: 0.9066
# Learning rate:  5e-07
# Epoch 183/200
# 1560/1563 [============================>.] - ETA: 0s - loss: 0.2054 - accuracy: 0.9696WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 1563/1563 [==============================] - 34s 22ms/step - loss: 0.2054 - accuracy: 0.9696 - val_loss: 0.4352 - val_accuracy: 0.9066
# Learning rate:  5e-07
# Epoch 184/200
# 1560/1563 [============================>.] - ETA: 0s - loss: 0.2033 - accuracy: 0.9706WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 1563/1563 [==============================] - 34s 22ms/step - loss: 0.2032 - accuracy: 0.9707 - val_loss: 0.4349 - val_accuracy: 0.9072
# Learning rate:  5e-07
# Epoch 185/200
# 1561/1563 [============================>.] - ETA: 0s - loss: 0.2046 - accuracy: 0.9702WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 1563/1563 [==============================] - 34s 22ms/step - loss: 0.2046 - accuracy: 0.9702 - val_loss: 0.4346 - val_accuracy: 0.9058
# Learning rate:  5e-07
# Epoch 186/200
# 1561/1563 [============================>.] - ETA: 0s - loss: 0.2063 - accuracy: 0.9692WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 1563/1563 [==============================] - 34s 22ms/step - loss: 0.2063 - accuracy: 0.9692 - val_loss: 0.4355 - val_accuracy: 0.9059
# Learning rate:  5e-07
# Epoch 187/200
# 1562/1563 [============================>.] - ETA: 0s - loss: 0.2034 - accuracy: 0.9711WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 1563/1563 [==============================] - 35s 22ms/step - loss: 0.2034 - accuracy: 0.9711 - val_loss: 0.4373 - val_accuracy: 0.9056
# Learning rate:  5e-07
# Epoch 188/200
# 1563/1563 [==============================] - ETA: 0s - loss: 0.2022 - accuracy: 0.9705WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 1563/1563 [==============================] - 34s 22ms/step - loss: 0.2022 - accuracy: 0.9705 - val_loss: 0.4359 - val_accuracy: 0.9060
# Learning rate:  5e-07
# Epoch 189/200
# 1563/1563 [==============================] - ETA: 0s - loss: 0.2020 - accuracy: 0.9713WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 1563/1563 [==============================] - 34s 22ms/step - loss: 0.2020 - accuracy: 0.9713 - val_loss: 0.4329 - val_accuracy: 0.9067
# Learning rate:  5e-07
# Epoch 190/200
# 1563/1563 [==============================] - ETA: 0s - loss: 0.2045 - accuracy: 0.9700WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 1563/1563 [==============================] - 34s 22ms/step - loss: 0.2045 - accuracy: 0.9700 - val_loss: 0.4359 - val_accuracy: 0.9064
# Learning rate:  5e-07
# Epoch 191/200
# 1563/1563 [==============================] - ETA: 0s - loss: 0.2047 - accuracy: 0.9702WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 1563/1563 [==============================] - 34s 22ms/step - loss: 0.2047 - accuracy: 0.9702 - val_loss: 0.4349 - val_accuracy: 0.9066
# Learning rate:  5e-07
# Epoch 192/200
# 1560/1563 [============================>.] - ETA: 0s - loss: 0.2025 - accuracy: 0.9702WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 1563/1563 [==============================] - 34s 22ms/step - loss: 0.2025 - accuracy: 0.9701 - val_loss: 0.4337 - val_accuracy: 0.9061
# Learning rate:  5e-07
# Epoch 193/200
# 1563/1563 [==============================] - ETA: 0s - loss: 0.2021 - accuracy: 0.9710WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 1563/1563 [==============================] - 34s 22ms/step - loss: 0.2021 - accuracy: 0.9710 - val_loss: 0.4343 - val_accuracy: 0.9064
# Learning rate:  5e-07
# Epoch 194/200
# 1562/1563 [============================>.] - ETA: 0s - loss: 0.2045 - accuracy: 0.9703WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 1563/1563 [==============================] - 35s 22ms/step - loss: 0.2045 - accuracy: 0.9703 - val_loss: 0.4337 - val_accuracy: 0.9068
# Learning rate:  5e-07
# Epoch 195/200
# 1562/1563 [============================>.] - ETA: 0s - loss: 0.2034 - accuracy: 0.9710WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 1563/1563 [==============================] - 35s 22ms/step - loss: 0.2034 - accuracy: 0.9710 - val_loss: 0.4343 - val_accuracy: 0.9062
# Learning rate:  5e-07
# Epoch 196/200
# 1561/1563 [============================>.] - ETA: 0s - loss: 0.2039 - accuracy: 0.9703WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 1563/1563 [==============================] - 35s 23ms/step - loss: 0.2040 - accuracy: 0.9703 - val_loss: 0.4333 - val_accuracy: 0.9065
# Learning rate:  5e-07
# Epoch 197/200
# 1562/1563 [============================>.] - ETA: 0s - loss: 0.2043 - accuracy: 0.9696WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 1563/1563 [==============================] - 35s 22ms/step - loss: 0.2044 - accuracy: 0.9696 - val_loss: 0.4369 - val_accuracy: 0.9062
# Learning rate:  5e-07
# Epoch 198/200
# 1560/1563 [============================>.] - ETA: 0s - loss: 0.2028 - accuracy: 0.9714WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 1563/1563 [==============================] - 35s 22ms/step - loss: 0.2028 - accuracy: 0.9714 - val_loss: 0.4342 - val_accuracy: 0.9062
# Learning rate:  5e-07
# Epoch 199/200
# 1562/1563 [============================>.] - ETA: 0s - loss: 0.2034 - accuracy: 0.9702WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 1563/1563 [==============================] - 35s 22ms/step - loss: 0.2033 - accuracy: 0.9702 - val_loss: 0.4339 - val_accuracy: 0.9076
# Learning rate:  5e-07
# Epoch 200/200
# 1561/1563 [============================>.] - ETA: 0s - loss: 0.2042 - accuracy: 0.9697WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 1563/1563 [==============================] - 35s 22ms/step - loss: 0.2042 - accuracy: 0.9697 - val_loss: 0.4343 - val_accuracy: 0.9065
# 313/313 [==============================] - 1s 4ms/step - loss: 0.4343 - accuracy: 0.9065
# Test loss: 0.434278279542923
# Test accuracy: 0.906499981880188
